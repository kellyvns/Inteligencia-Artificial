# %%
num1 = input("Digite o primeiro número: ")
num2 = input("Digite o segundo número: ")
num3 = input("Digite o segundo número: ")

maior = max(num1, num2, num3)

print(f"O maior número é: {maior}")
